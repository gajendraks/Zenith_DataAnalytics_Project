# %%
#visualization 1
import time
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


sns.set_style("darkgrid")
plt.rcParams['figure.figsize'] = (14, 8)

df=pd.read_csv("./../../Data/a.csv",low_memory=False)
print(df.head())
columns=[]
ipl=df.drop(columns=['ball','innings','delivery','team','non_striker','extra_run','wicket_kind','player_out'])
ipl=ipl[['bowler','batsman','runs']].groupby(['batsman'])['runs'].sum().reset_index(name='batsman_run')
a=list(ipl['batsman'])
b=list(ipl['batsman_run'])
c=list(zip(a,b))
def sortbyval(a): # sorts the list by number of runs
    return a[1]
def bestbats(d): #finds top 20 batsman who have scored most number of runs
    bat=list()
    for i in d[0:20]:
        bat.append(i)
    return bat
def ext(e): # returns a list of runs scored by top 20 batsmen
    k=list()
    s=list()
    l=list()
    for i in e:
        for j in i:
               if(type(j) is str):
                    s.append(j)
               else :
                    k.append(j)
            
    
    return k
def ext1(e): #returns a list of top 20 batsman names
    k=list()
    s=list()
    l=list()
    for i in e:
        for j in i:
               if(type(j) is str):
                    s.append(j)
               else :
                    k.append(j)
            
    
    return s
def plotbestbat(g,f): #plots a bar graph of batsmen and number of runs
    plt.bar(range(len(g)),f)
    plt.xlabel('Batsman', fontsize=5)
    plt.ylabel('Runs', fontsize=5)
    plt.xticks(range(len(g)),g, fontsize=5, rotation=30)
    plt.title('Batsman runs')
    plt.show()
d=sorted(c,key=sortbyval,reverse=True)
e=bestbats(d)
f=ext(e)
g=ext1(e)
print(g)
plotbestbat(g,f)
# Out:
#    ball  innings  delivery            team   batsman   non_striker  \
# 0  ball        1       0.1  Mumbai Indians  HH Gibbs  SR Tendulkar
# 1  ball        1       0.2  Mumbai Indians  HH Gibbs  SR Tendulkar
# 2  ball        1       0.3  Mumbai Indians  HH Gibbs  SR Tendulkar
# 3  ball        1       0.4  Mumbai Indians  HH Gibbs  SR Tendulkar
# 4  ball        1       0.5  Mumbai Indians  HH Gibbs  SR Tendulkar
#
#             bowler  runs  extra_run wicket_kind player_out
# 0  Shakib Al Hasan     0          0         NaN        NaN
# 1  Shakib Al Hasan     0          0         NaN        NaN
# 2  Shakib Al Hasan     0          0         NaN        NaN
# 3  Shakib Al Hasan     0          0         NaN        NaN
# 4  Shakib Al Hasan     0          0         NaN        NaN
# ['SK Raina', 'V Kohli', 'RG Sharma', 'G Gambhir', 'DA Warner', 'RV Uthappa', 'CH Gayle', 'S Dhawan', 'MS Dhoni', 'AB de Villiers', 'AM Rahane', 'YK Pathan', 'KD Karthik', 'BB McCullum', 'V Sehwag', 'SR Watson', 'Yuvraj Singh', 'M Vijay', 'SE Marsh', 'JH Kallis']

# %%
#visualisation2
import time
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("./../../Data/a.csv",low_memory=False)
columns=[]
ipl=df.drop(columns=['ball','innings','delivery','team','non_striker','extra_run','wicket_kind','player_out'])
ipl=ipl[['bowler','batsman','runs']].groupby(['batsman'])['runs'].mean().reset_index(name='strike_rate')

def calculate_sr(i):
    return i * 100
def sortbyval(a): # sorts the list by number of runs
    return a[1]
def bestsr(d): #finds top 20 batsman who have scored most number of runs
    bat=list()
    for i in d[0:20]:
        bat.append(i)
    return bat
def ext(e): # returns a list of runs scored by top 20 batsmen
    k=list()
    s=list()
    l=list()
    for i in e:
        for j in i:
               if(type(j) is str):
                    s.append(j)
               else :
                    k.append(j)
            
    
    return k
def ext1(e): #returns a list of top 20 batsman names
    k=list()
    s=list()
    l=list()
    for i in e:
        for j in i:
               if(type(j) is str):
                    s.append(j)
               else :
                    k.append(j)
            
    
    return s
def plotbestsr(g,f): #plots a bar graph of batsmen and number of runs
    plt.bar(range(len(g)),f)
    plt.xlabel('Batsman', fontsize=5)
    plt.ylabel('Runs', fontsize=5)
    plt.xticks(range(len(g)),g, fontsize=5, rotation=30)
    plt.title('Batsman runs')
    plt.show()
a=calculate_sr(ipl['strike_rate'])
b=list(ipl['batsman'])
c=list(zip(b,a))
d=sorted(c,key=sortbyval,reverse=True)
e=bestsr(d)
print(g)
f=ext(e)
g=ext1(e)
plotbestsr(g,f)
# Out:
# ['DL Chahar', 'Umar Gul', 'RS Sodhi', 'BCJ Cutting', 'AJ Tye', 'Shahid Afridi', 'I Malhotra', 'SN Khan', 'CR Brathwaite', 'LJ Wright', 'KMDN Kulasekara', 'Shivam Sharma', 'KK Cooper', 'Kamran Akmal', 'AD Russell', 'BJ Haddin', 'KJ Abbott', 'ER Dwivedi', 'CH Morris', 'GJ Maxwell']

# %%
#visualization3
import time
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
def sortbyval(a): # sorts the list by number of runs
    return a[1]
def plotbestavg(g,f): #plots a bar graph of batsmen and number of runs
    plt.bar(range(len(g)),f)
    plt.xlabel('Batsman', fontsize=5)
    plt.ylabel('Average', fontsize=5)
    plt.xticks(range(len(g)),g, fontsize=5, rotation=30)
    plt.title('Batsman average')
    plt.show()
def ext(e): # returns a list of runs scored by top 20 batsmen
    k=list()
    s=list()
    l=list()
    for i in e:
        for j in i:
               if(type(j) is str):
                    s.append(j)
               else :
                    k.append(j)
            
    
    return k
def ext1(e): #returns a list of top 20 batsman names
    k=list()
    s=list()
    l=list()
    for i in e:
        for j in i:
               if(type(j) is str):
                    s.append(j)
               else :
                    k.append(j)
            
    
    return s



    

df=pd.read_csv("./../../Data/a.csv",low_memory=False)
columns=[]
ipl=df.drop(columns=['delivery','non_striker','extra_run'])
balls=ipl[['bowler','batsman','runs','ball']].groupby(['batsman'])['ball'].size().reset_index(name = 'Number_of_balls')
wick=ipl[['player_out','wicket_kind']].groupby(['player_out'])['wicket_kind'].size().reset_index(name = 'Number_of_wickets')

runs=ipl[['bowler','batsman','runs']].groupby(['batsman'])['runs'].sum().reset_index(name = 'Number_of_runs')
a=list(wick['Number_of_wickets'])
b=list(runs['Number_of_runs'])

c=list(wick['player_out'])
d=list(runs['batsman'])
e=list(wick['Number_of_wickets'])
f=list(runs['Number_of_runs'])
k=dict(zip(c,e))
j=dict(zip(d,f))
m=j.keys()-k.keys()
n=k.keys()-j.keys()
#print(m)
#print(n)
for i in m:
    del j[i]
for i in n:
    del k[i]
print(len(k),len(j))
#print(k,j
k1=list(k.values())
k2=list(j.values())
k3=[a/b for a,b in zip(k2,k1)]
k4=list(j.keys())
k5=list(zip(k4,k3))

k6=sorted(k5,key=sortbyval,reverse=True)

print(k6[0:50])#returns a list of top 20 best batsmen with best averages
k7=ext1(k6[0:20])
k8=ext(k6[0:20])

plotbestavg(k7,k8)
# Out:
# 435 435
# [('MN van Wyk', 55.666666666666664), ('V Shankar', 50.5), ('J Suchith', 48.0), ('AC Voges', 45.25), ('HM Amla', 44.38461538461539), ('Iqbal Abdulla', 44.0), ('CH Gayle', 41.02247191011236), ('PD Collingwood', 40.6), ('DA Warner', 40.14), ('LMP Simmons', 39.96296296296296), ('JP Duminy', 39.86), ('SE Marsh', 39.507936507936506), ('MEK Hussey', 38.76470588235294), ('CA Lynn', 38.4), ('AB de Villiers', 38.30769230769231), ('MS Dhoni', 37.87234042553192), ('V Kohli', 37.483050847457626), ('SPD Smith', 37.23913043478261), ('CH Morris', 36.583333333333336), ('A Symonds', 36.074074074074076), ('AN Ahmed', 36.0), ('KP Pietersen', 35.75), ('ML Hayden', 35.70967741935484), ('B Sumanth', 35.0), ('DA Miller', 34.733333333333334), ('KH Pandya', 34.285714285714285), ('SK Raina', 33.940298507462686), ('SR Tendulkar', 33.82608695652174), ('OA Shah', 33.733333333333334), ('AM Rahane', 33.59340659340659), ('BJ Hodge', 33.333333333333336), ('S Dhawan', 32.669724770642205), ('RG Sharma', 32.6124031007752), ('D Wiese', 31.75), ('KS Williamson', 31.615384615384617), ('BA Stokes', 31.6), ('G Gambhir', 31.541984732824428), ('N Rana', 31.214285714285715), ('A Flintoff', 31.0), ('SR Watson', 30.91764705882353), ('S Badrinath', 30.659574468085108), ('Niraj Patel', 30.25), ('KL Rahul', 30.208333333333332), ('F du Plessis', 30.11627906976744), ('YK Pathan', 29.816326530612244), ('JEC Franklin', 29.727272727272727), ('RV Uthappa', 29.515625), ('JJ Roy', 29.5), ('RS Bopara', 29.5), ('SN Khan', 29.5)]

# %%
#visualization4
import time
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
def sortbyval(a):
    return a[1]
def outs(a):
    if a['wicket_kind'] is "runout":
        del a['wicket_kind']
        print("hi")
    return a
df=pd.read_csv("./../../Data/a.csv",low_memory=False)
df.replace('run out',np.nan)
columns=[]
ipl=df.drop(columns=['innings','delivery','non_striker'])
ipl1=ipl[['bowler','batsman','runs','team']].groupby(['team'])['runs'].sum().reset_index(name='tot')

ipl2=ipl[['bowler','wicket_kind','team','player_out']].groupby(['bowler','player_out'])['wicket_kind'].size().reset_index(name='wic')
ipl3=ipl2[['bowler','player_out','wic']].groupby(['bowler'])['wic'].sum().reset_index(name='wickets')
ipl4=ipl[['bowler','player_out','runs']].groupby(['bowler'])['runs'].sum().reset_index(name='cruns')
ipl5=ipl[['bowler','ball']].groupby(['bowler'])['ball'].size().reset_index(name="balls")
ipl6=ipl[['batsman','bowler','extra_run']].groupby(['bowler','batsman'])['extra_run'].sum().reset_index(name='xr')
ipl7=ipl6[['bowler','xr']].groupby(['bowler'])['xr'].sum().reset_index(name="Extras")
bw=list(ipl7['bowler'])
xr=list(ipl7['Extras'])
br=list(zip(bw,xr))
br=sorted(br,key=sortbyval,reverse=True)
print(br)# bowlers and extras bowled

a=ipl3['bowler']
b=ipl3['wickets']
c=list(zip(a,b))
d=sorted(c,key=sortbyval,reverse=True)

e=ipl4['bowler']
d1=ipl4['cruns']

f=dict(zip(a,b))
g=dict(zip(e,d1))
h=g.keys()-f.keys()
l=list()
for i in h:
    l.append((i,g[i]))
    del g[i]
#print(len(f),len(g))
wu=list(f.values())#list of wickets
ru=list(g.values())#list of runs
na=list(g.keys())

avg=[b/a for a,b in zip(wu,ru)]
la=list(zip(na,avg))
print(la)
print(l)#prints a list of bowlers who have never taken a wicket
# Out:
# [('SL Malinga', 268), ('P Kumar', 236), ('UT Yadav', 186), ('RP Singh', 181), ('Z Khan', 169), ('I Sharma', 167), ('B Kumar', 166), ('DW Steyn', 166), ('SR Watson', 162), ('Harbhajan Singh', 158), ('DJ Bravo', 157), ('JA Morkel', 153), ('R Ashwin', 143), ('IK Pathan', 142), ('PP Ojha', 138), ('L Balaji', 131), ('M Morkel', 131), ('DS Kulkarni', 127), ('JH Kallis', 126), ('M Muralitharan', 123), ('PP Chawla', 117), ('AB Dinda', 116), ('A Nehra', 115), ('A Mishra', 114), ('R Vinay Kumar', 114), ('SW Tait', 111), ('S Sreesanth', 109), ('JP Faulkner', 105), ('SK Trivedi', 104), ('VR Aaron', 99), ('MG Johnson', 98), ('KA Pollard', 97), ('RJ Harris', 87), ('SP Narine', 86), ('B Lee', 84), ('Sandeep Sharma', 84), ('MJ McClenaghan', 83), ('RA Jadeja', 83), ('DP Nannes', 81), ('PJ Sangwan', 81), ('WD Parnell', 80), ('CH Morris', 77), ('M Kartik', 77), ('Mohammed Shami', 76), ('CH Gayle', 75), ('R Bhatia', 73), ('AR Patel', 71), ('YK Pathan', 71), ('JJ Bumrah', 69), ('MA Starc', 69), ('YS Chahal', 68), ('MS Gony', 67), ('KK Cooper', 64), ('MM Patel', 63), ('A Kumble', 62), ('AB Agarkar', 62), ('SK Warne', 57), ('DT Christian', 56), ('DE Bollinger', 53), ('HV Patel', 53), ('SB Jakati', 52), ('Shakib Al Hasan', 51), ('S Aravind', 50), ('R Dhawan', 49), ('AN Ahmed', 48), ('Harmeet Singh', 48), ('PJ Cummins', 48), ('AD Russell', 47), ('TG Southee', 47), ('KV Sharma', 46), ('P Awana', 46), ('JP Duminy', 45), ('MM Sharma', 45), ('MC Henriques', 43), ('NM Coulter-Nile', 43), ('SK Raina', 43), ('Iqbal Abdulla', 42), ('AD Mathews', 41), ('Imran Tahir', 40), ('A Symonds', 38), ('DR Smith', 38), ('MF Maharoof', 38), ('R McLaren', 38), ('J Botha', 37), ('RR Powar', 37), ('S Nadeem', 37), ('A Singh', 36), ('BW Hilfenhaus', 36), ('Anureet Singh', 35), ('JD Unadkat', 35), ('SJ Srivastava', 35), ('GB Hogg', 33), ('NLTC Perera', 33), ('VY Mahesh', 33), ('PV Tambe', 32), ('S Kaul', 32), ('Umar Gul', 32), ('BB Sran', 30), ('TA Boult', 30), ('A Mithun', 29), ('LR Shukla', 29), ('RE van der Merwe', 29), ('Sohail Tanvir', 29), ('P Negi', 28), ('CJ Jordan', 27), ('CRD Fernando', 27), ('HH Pandya', 27), ('Azhar Mahmood', 26), ('KH Pandya', 26), ('Yuvraj Singh', 26), ('AS Rajpoot', 25), ('IC Pandey', 25), ('RS Bopara', 25), ('Bipul Sharma', 24), ('DL Vettori', 24), ('K Rabada', 24), ('RG Sharma', 24), ('J Theron', 23), ('JR Hopes', 23), ('AC Thomas', 22), ('BA Stokes', 22), ('AA Chavan', 21), ('CJ Anderson', 21), ('CK Langeveldt', 21), ('CR Woakes', 21), ('R Sharma', 21), ('SN Thakur', 21), ('ST Jayasuriya', 21), ('JDP Oram', 20), ('Kamran Khan', 20), ('R Rampaul', 20), ('S Badree', 20), ('S Tyagi', 20), ('AF Milne', 19), ('BA Bhatt', 19), ('D Wiese', 19), ('JO Holder', 19), ('Joginder Sharma', 19), ('KW Richardson', 19), ('M Ntini', 19), ('MP Stoinis', 19), ('Pankaj Singh', 19), ('R Shukla', 19), ('STR Binny', 19), ('WPUJC Vaas', 19), ('AG Murtaza', 18), ('Anand Rajan', 18), ('DJ Hussey', 18), ('Kuldeep Yadav', 18), ('MR Marsh', 18), ('Mohammad Asif', 18), ('VRV Singh', 18), ('Ankit Sharma', 17), ('GJ Maxwell', 17), ('JD Ryder', 17), ('Mustafizur Rahman', 17), ('Shahid Afridi', 17), ('V Kohli', 17), ('YA Abdulla', 17), ('BJ Hodge', 16), ('FH Edwards', 16), ('Rashid Khan', 16), ('SB Wagh', 16), ('AM Salvi', 15), ('BE Hendricks', 15), ('JE Taylor', 15), ('A Ashish Reddy', 14), ('Basil Thampi', 14), ('GD McGrath', 14), ('M de Lange', 14), ('P Suyal', 14), ('RR Raje', 14), ('VS Malik', 14), ('CR Brathwaite', 13), ('DJG Sammy', 13), ('DP Vijaykumar', 13), ('KP Appanna', 13), ('KP Pietersen', 13), ('S Kaushik', 13), ('SM Harwood', 13), ('TS Mills', 13), ('AD Mascarenhas', 12), ('AM Nayar', 12), ('DJ Hooda', 12), ('Jaskaran Singh', 12), ('KJ Abbott', 12), ('LH Ferguson', 12), ('T Thushara', 12), ('A Zampa', 11), ('B Akhil', 11), ('BAW Mendis', 11), ('Karanveer Singh', 11), ('M Ashwin', 11), ('SC Ganguly', 11), ('V Pratap Singh', 11), ('D Salunkhe', 10), ('J Suchith', 10), ('Mohammad Hafeez', 10), ('SM Pollock', 10), ('Shoaib Malik', 10), ('AP Dole', 9), ('JEC Frankli ...
# [('A Ashish Reddy', 20.31578947368421), ('A Chandila', 22.0), ('A Choudhary', 27.4), ('A Flintoff', 52.5), ('A Kumble', 20.959183673469386), ('A Mishra', 22.471830985915492), ('A Mithun', 56.0), ('A Nehra', 20.016528925619834), ('A Nel', 31.0), ('A Singh', 19.451612903225808), ('A Symonds', 28.52173913043478), ('A Uniyal', 21.333333333333332), ('A Zampa', 14.210526315789474), ('AA Chavan', 39.75), ('AA Jhunjhunwala', 126.0), ('AA Kazi', 20.0), ('AA Noffke', 35.0), ('AB Agarkar', 33.696969696969695), ('AB Dinda', 24.23170731707317), ('AB McDonald', 18.5), ('AC Gilchrist', 0.0), ('AC Thomas', 24.625), ('AC Voges', 74.0), ('AD Mascarenhas', 18.57894736842105), ('AD Mathews', 37.642857142857146), ('AD Russell', 24.166666666666668), ('AF Milne', 33.2), ('AG Murtaza', 25.333333333333332), ('AJ Finch', 66.0), ('AJ Tye', 11.583333333333334), ('AL Menaria', 46.666666666666664), ('AM Nayar', 34.55555555555556), ('AM Rahane', 5.0), ('AM Salvi', 27.142857142857142), ('AN Ahmed', 31.133333333333333), ('AP Dole', 21.0), ('AR Patel', 24.80327868852459), ('AS Rajpoot', 28.25), ('Anand Rajan', 18.8), ('Ankit Sharma', 35.416666666666664), ('Ankit Soni', 35.25), ('Anureet Singh', 29.42105263157895), ('Avesh Khan', 23.0), ('Azhar Mahmood', 21.967741935483872), ('B Akhil', 33.57142857142857), ('B Geeves', 45.0), ('B Kumar', 19.17948717948718), ('B Laughlin', 68.0), ('B Lee', 34.733333333333334), ('B Stanlake', 34.0), ('BA Bhatt', 29.923076923076923), ('BA Stokes', 21.785714285714285), ('BAW Mendis', 32.77777777777778), ('BB Sran', 32.5), ('BCJ Cutting', 25.555555555555557), ('BE Hendricks', 20.363636363636363), ('BJ Hodge', 16.333333333333332), ('BMAJ Mendis', 36.0), ('BW Hilfenhaus', 20.043478260869566), ('Basil Thampi', 27.6), ('Bipul Sharma', 25.318181818181817), ('C Nanda', 27.5), ('C de Grandhomme', 32.25), ('CH Gayle', 35.526315789473685), ('CH Morris', 19.838709677419356), ('CJ Anderson', 43.0), ('CJ Jordan', 17.785714285714285), ('CJ McKay', 60.0), ('CK Langeveldt', 13.692307692307692), ('CL White', 81.0), ('CR Brathwaite', 24.6), ('CR Woakes', 20.666666666666668), ('CRD Fernando', 14.68421052631579), ('D Kalyankrishna', 42.5), ('D Salunkhe', 70.0), ('D Wiese', 22.941176470588236), ('D du Preez', 13.75), ('DAJ Bracewell', 10.333333333333334), ('DB Ravi Teja', 28.0), ('DE Bollinger', 15.418604651162791), ('DJ Bravo', 19.401459854014597), ('DJ Hooda', 43.0), ('DJ Hussey', 46.7), ('DJ Muthuswami', 25.25), ('DJ Thornely', 12.666666666666666), ('DJG Sammy', 24.357142857142858), ('DL Chahar', 110.0), ('DL Vettori', 25.58823529411765), ('DNT Zoysa', 48.0), ('DP Nannes', 19.31578947368421), ('DP Vijaykumar', 48.0), ('DR Smith', 29.14814814814815), ('DS Kulkarni', 22.11111111111111), ('DT Christian', 28.125), ('DW Steyn', 22.09), ('FH Edwards', 24.0), ('FY Fazal', 20.0), ('GB Hogg', 22.08), ('GD McGrath', 25.142857142857142), ('GH Vihari', 37.0), ('GJ Maxwell', 38.833333333333336), ('GR Napier', 27.0), ('GS Sandhu', 82.0), ('Gagandeep Singh', 47.0), ('Gurkeerat Singh', 18.6), ('HH Pandya', 52.5), ('HV Patel', 25.56756756756757), ('Harbhajan Singh', 24.227941176470587), ('Harmeet Singh', 22.166666666666668), ('Harmeet Singh (2)', 33.0), ('I Sharma', 36.0), ('IC Pandey', 30.736842105263158), ('IK Pathan', 25.949494949494948), ('Imran Tahir', 19.24), ('Iqbal Abdulla', 24.066666666666666), ('J Botha', 28.925925925925927), ('J Suchith', 35.9), ('J Syed Mohammad', 27.9), ('J Theron', 22.153846153846153), ('J Yadav', 48.25), ('JA Morkel', 23.5), ('JD Ryder', 27.0), ('JD Unadkat', 21.55), ('JDP Oram', 26.307692307692307), ('JDS Neesham', 88.0), ('JE Taylor', 25.333333333333332), ('JEC Franklin', 24.0), ('JH Kallis', 30.027027027027028), ('JJ Bumrah', 25.735849056603772), ('JJ van der Wath', 41.666666666666664), ('JM Kemp', 17.0), ('JO Holder', 36.75), ('JP Duminy', 33.30434782608695), ('JP Faulkner', 22.94736842105263), ('JR Hopes', 38.5), ('JW Hastings', 21.0), ('Jaskaran Singh', 27.0), ('Joginder Sharma', 30.923076923076923), ('K Rabada', 21.75), ('K San ...
# [('SPD Smith', 5), ('C Ganapathy', 13), ('DJ Harris', 26), ('RR Bose', 24), ('AS Raut', 44), ('RW Price', 33), ('K Goel', 92), ('Y Gnaneswara Rao', 7), ('SA Abbott', 55), ('RA Shaikh', 11), ('MG Neser', 61), ('V Shankar', 19), ('K Upadhyay', 79), ('NL McCullum', 34), ('VS Yeligati', 53), ('LPC Silva', 21), ('LRPL Taylor', 23), ('MB Parmar', 32), ('KAJ Roach', 76), ('RA Tripathi', 12), ('Abdur Razzak', 23), ('M Vijay', 48), ('CK Kapugedera', 49), ('M Manhas', 42), ('C Munro', 15), ('S Sriram', 49), ('NJ Rimmington', 19), ('S Rana', 18), ('Sunny Gupta', 45), ('P Prasanth', 18), ('B Chipli', 20), ('N Rana', 3), ('SA Yadav', 8), ('RS Gavaskar', 8), ('AUK Pathan', 57), ('KS Williamson', 7), ('I Malhotra', 23), ('Tejas Baroka', 33), ('F du Plessis', 16), ('BJ Rohrer', 11), ('SR Tendulkar', 57), ('RR Bhatkal', 35)]
